# %% [markdown]
# ## Meson $u-d$

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Read the file. Radius and Correlations

W1 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T1/fort.13', 'r')
W2 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T2/fort.13', 'r')
W3 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T3/fort.13', 'r')
W4 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T4/fort.13', 'r')
W5 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T5/fort.13', 'r')
W6 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T6/fort.13', 'r')
W7 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T7/fort.13', 'r')
W8 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T8/fort.13', 'r')
W9 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T9/fort.13', 'r')
W10 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T10/fort.13', 'r')

V1 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T1/fort.8', 'r')
V2 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T2/fort.8', 'r')
V3 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T3/fort.8', 'r')
V4 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T4/fort.8', 'r')
V5 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T5/fort.8', 'r')
V6 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T6/fort.8', 'r')
V7 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T7/fort.8', 'r')
V8 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T8/fort.8', 'r')
V9 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T9/fort.8', 'r')
V10 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T10/fort.8', 'r')

R1 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T1/r2meson.dat', 'r')
R2 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T2/r2meson.dat', 'r')
R3 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T3/r2meson.dat', 'r')
R4 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T4/r2meson.dat', 'r')
R5 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T5/r2meson.dat', 'r')
R6 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T6/r2meson.dat', 'r')
R7 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T7/r2meson.dat', 'r')
R8 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T8/r2meson.dat', 'r')
R9 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T9/r2meson.dat', 'r')
R10 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T10/r2meson.dat', 'r')

Cqq1 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T1/corrqq.dat', 'r')
Cqq2 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T2/corrqq.dat', 'r')
Cqq3 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T3/corrqq.dat', 'r')
Cqq4 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T4/corrqq.dat', 'r')
Cqq5 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T5/corrqq.dat', 'r')
Cqq6 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T6/corrqq.dat', 'r')
Cqq7 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T7/corrqq.dat', 'r')
Cqq8 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T8/corrqq.dat', 'r')
Cqq9 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T9/corrqq.dat', 'r')
Cqq10 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T10/corrqq.dat', 'r')

Cqqbar1 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T1/corrqqbar.dat', 'r')
Cqqbar2 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T2/corrqqbar.dat', 'r')
Cqqbar3 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T3/corrqqbar.dat', 'r')
Cqqbar4 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T4/corrqqbar.dat', 'r')
Cqqbar5 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T5/corrqqbar.dat', 'r')
Cqqbar6 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T6/corrqqbar.dat', 'r')
Cqqbar7 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T7/corrqqbar.dat', 'r')
Cqqbar8 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T8/corrqqbar.dat', 'r')
Cqqbar9 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T9/corrqqbar.dat', 'r')
Cqqbar10 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T10/corrqqbar.dat', 'r')

Cqall1 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T1/corrqall.dat', 'r')
Cqall2 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T2/corrqall.dat', 'r')
Cqall3 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T3/corrqall.dat', 'r')
Cqall4 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T4/corrqall.dat', 'r')
Cqall5 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T5/corrqall.dat', 'r')
Cqall6 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T6/corrqall.dat', 'r')
Cqall7 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T7/corrqall.dat', 'r')
Cqall8 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T8/corrqall.dat', 'r')
Cqall9 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T9/corrqall.dat', 'r')
Cqall10 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T10/corrqall.dat', 'r')


Cmm1 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T1/corrmm.dat', 'r')
Cmm2 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T2/corrmm.dat', 'r')
Cmm3 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T3/corrmm.dat', 'r')
Cmm4 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T4/corrmm.dat', 'r')
Cmm5 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T5/corrmm.dat', 'r')
Cmm6 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T6/corrmm.dat', 'r')
Cmm7 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T7/corrmm.dat', 'r')
Cmm8 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T8/corrmm.dat', 'r')
Cmm9 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T9/corrmm.dat', 'r')
Cmm10 = open('/Users/ivantoledano/Documents/Tesis Maestria/Algoritmos 2/Analisis/CounterMeson/Cud/T10/corrmm.dat', 'r')




# Arreglos de datos para el loop 
W = [W1,W2,W3,W4,W5,W6,W7,W8,W9,W10]
V = [V1,V2,V3,V4,V5,V6,V7,V8,V9,V10]
R = [R1,R2,R3,R4,R5,R6,R7,R8,R9,R10]
Cqq = [Cqq1,Cqq2,Cqq3,Cqq4,Cqq5,Cqq6,Cqq7,Cqq8,Cqq9,Cqq10]
Cqqbar = [Cqqbar1,Cqqbar2,Cqqbar3,Cqqbar4,Cqqbar5,Cqqbar6,Cqqbar7,Cqqbar8,Cqqbar9,Cqqbar10]
Cqall = [Cqall1,Cqall2,Cqall3,Cqall4,Cqall5,Cqall6,Cqall7,Cqall8,Cqall9,Cqall10]
Cmm = [Cmm1,Cmm2,Cmm3,Cmm4,Cmm5,Cmm6,Cmm7,Cmm8,Cmm9,Cmm10]

# Datos a graficar

Energia1 = []
ErrorEnergia1 = []

Kinetic1 = []
ErrorKinetic1 = []

Potential1 = []
ErrorPotential1 = []

Radio1= []
ErrorRadio1 = []

Densidad1 = [0.000001,0.001,0.005,0.01,0.03,0.05,0.07,0.1,0.2,0.3]

# Funcion de termino cinetico del gas de Fermi
def Tfg(p1,p2,p3,masa,Long):
    return (1./(8.*masa*Long**2))*(p1**2+p2**2+p3**2)

Masaq = 1.0
MasaQ = 1.0
#MasaQ = 486./336.
#MasaQ = 1550./336.
#MasaQ = 14.077



for i in range(0,len(W)):

    linesW = W[i].readlines()
    linesV = V[i].readlines()
    linesR = R[i].readlines()
    linesCqq = Cqq[i].readlines()
    linesCqqbar = Cqqbar[i].readlines()
    linesCqall = Cqall[i].readlines()
    linesCmm = Cmm[i].readlines()
    
    W[i].close()
    V[i].close()
    R[i].close()
    Cqq[i].close()
    Cqqbar[i].close()
    Cqall[i].close()
    Cmm[i].close()
    
    Longitud = (4./Densidad1[i])**(1./3.)
    Fermi = Tfg(1.,1.,1.,Masaq,Longitud) + Tfg(1.,1.,1.,Masaq,Longitud) + Tfg(1.,1.,1.,MasaQ,Longitud) + Tfg(1.,1.,1.,MasaQ,Longitud)



    # Creamos nuevos valores
    # Listas de valores de los archivos
    cW = []
    ceW = []
    
    cV = []
    ceV = []
    
    cR = []
    cCqq = []
    cCqqbar = []
    cCqall = []
    cCmm = []

    CRpromedio = 0.0   # Suma de valores de R^2

    Rpromedio = 0.0     #Suma por bloque
    eRpromedio = 0.0    #Erros por bloque

    Iblock = 50         #Tamano del bloque
    Icount = 0          #Contador hasta bloque
    Noblock = 0         #Numero de bloques de datos

    #Poner en lista valor promedio del termino cinetico (incluyendo Fermi)
    for line in linesW:
        p = line.split()
        Kinetic1.append((1./Masaq)*float(p[1]) + (1./Masaq)*float(p[3]) + (1./MasaQ)*float(p[5]) + (1./MasaQ)*float(p[7]) + Fermi)
        ErrorKinetic1.append(float(p[2]) + float(p[4]) + float(p[6]) + float(p[8]))
    
    #Poner en lista valor promedio del termino potencial
    for line in linesV:
        p = line.split()
        Potential1.append(float(p[1]))
        ErrorPotential1.append(float(p[2]))
    
    
    #Reconstruimos energia total y la ponemos en una lista    
    Energia1.append(Kinetic1[i]+Potential1[i])
    ErrorEnergia1.append(ErrorKinetic1[i] + ErrorPotential1[i])
    
    
    #Radio al cuadrado
    for line in linesR:
        Icount = Icount + 1
    
        p = line.split()       #Usamos p como una variable intermediaria
        cR.append(np.sqrt(float(p[0])/2.))
    #    c1.append(float(p[0])/2.)
    
        CRpromedio = CRpromedio + float(p[0])/2.
    
        if (Icount == Iblock):
        
            Noblock = Noblock + 1
        
            Rpromedio = Rpromedio + float(CRpromedio)/float(Iblock)
            eRpromedio = eRpromedio + (float(CRpromedio)/float(Iblock))**2.
        
            CRpromedio = 0.0
            Icount = 0
            
    #Correlaciones
    
    for line in linesCqq:
        p = line.split()
        cCqq.append(float(p[0]))
        
    for line in linesCqqbar:
        p = line.split()
        cCqqbar.append(float(p[0]))
        
    for line in linesCqall:
        p = line.split()
        cCqall.append(float(p[0]))
        
    for line in linesCmm:
        p = line.split()
        cCmm.append(float(p[0]))
    

    

    print 'leng',len(cR),Noblock, 'rho=',Densidad1[i], 'Longitud =', Longitud  
    print 'Radio cuadrado promedio', float(Rpromedio)/float(Noblock)
    print 'Error radio', np.sqrt((float(eRpromedio)/float(Noblock)-(float(Rpromedio)/float(Noblock))**2.)/float(Noblock))
    
    Radio1.append(float(Rpromedio)/float(Noblock))
    ErrorRadio1.append(np.sqrt((float(eRpromedio)/float(Noblock)-(float(Rpromedio)/float(Noblock))**2.)/float(Noblock)))
    
    xR = np.array(cR)
    xCqq = np.array(cCqq)
    xCqqbar = np.array(cCqqbar)
    xCqall = np.array(cCqall)
    xCmm = np.array(cCmm)
       

    #plt.hist(xc, bins=40,normed=1)
    #plt.xlabel("r", fontsize=15)
    #plt.ylabel("Cuentas", fontsize=15)
    #plt.savefig('/Users/ivantoledano/Documents/Maestría/Documentos Posgrado/Reporte Semestral 2/Imagenes/Radio1.eps', format='eps', dpi=1000)
    #plt.show()


    #........Espectro de radios al cuadrado........
    
    counts,bin_edges = np.histogram(xR,40)
    bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
    plt.plot(bin_centres,counts,'o')
    plt.title("Distribucion de raiz del radio al cuadrado")
    plt.xlabel("$(r^2)^{1/2}$", fontsize=15)
    plt.ylabel("Cuentas", fontsize=15)    
    #err = np.random.rand(bin_centres.size)*100
    #pp.errorbar(bin_centres, counts, yerr=err, fmt='o')
    plt.show()
    
    #.......Espectro de correlaciones.........
    
    counts,bin_edges = np.histogram(xCqq,40,normed=1.)
    bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
    counts[0] = 0.00
    plt.plot(bin_centres,counts,'o')
    plt.title("Correlacion $q-q$")
    plt.xlabel("r", fontsize=15)
    plt.ylabel("Cuentas", fontsize=15)
    plt.show()
    
    counts,bin_edges = np.histogram(xCqqbar,40,normed=1.)
    bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
    counts[0] = 0.00
    plt.plot(bin_centres,counts,'o')
    plt.title("Correlacion $q-qbar$")
    plt.xlabel("r", fontsize=15)
    plt.ylabel("Cuentas", fontsize=15)
    plt.show()
    
    counts,bin_edges = np.histogram(xCqall,40,normed=1.)
    bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
    counts[0] = 0.00    
    plt.plot(bin_centres,counts,'o')
    plt.title("Correlacion $q-all$")
    plt.xlabel("r", fontsize=15)
    plt.ylabel("Cuentas", fontsize=15)
    plt.show()
    
    counts,bin_edges = np.histogram(xCmm,40,normed=1.)
    bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
    counts[0] = 0.00
    plt.plot(bin_centres,counts,'o')
    plt.title("Correlacion Meson-Meson")
    plt.xlabel("r", fontsize=15)
    plt.ylabel("Cuentas", fontsize=15)
    plt.show()
# Out:
# leng 60000 1200 rho= 1e-06 Longitud = 158.740105197
# Radio cuadrado promedio 1.50785992314
# Error radio 0.00413791048923
# leng 60000 1200 rho= 0.001 Longitud = 15.8740105197
# Radio cuadrado promedio 1.42587478687
# Error radio 0.00394414959449
# leng 60000 1200 rho= 0.005 Longitud = 9.28317766723
# Radio cuadrado promedio 1.40594395561
# Error radio 0.00377893298961
# leng 60000 1200 rho= 0.01 Longitud = 7.36806299728
# Radio cuadrado promedio 1.46091382505
# Error radio 0.00378640626184
# leng 60000 1200 rho= 0.03 Longitud = 5.10872954929
# Radio cuadrado promedio 1.39698306537
# Error radio 0.002806814589
# leng 60000 1200 rho= 0.05 Longitud = 4.30886938006
# Radio cuadrado promedio 1.15687816901
# Error radio 0.00225770714279
# leng 60000 1200 rho= 0.07 Longitud = 3.85171357111
# Radio cuadrado promedio 0.977400726872
# Error radio 0.00181465855459
# leng 60000 1200 rho= 0.1 Longitud = 3.41995189335
# Radio cuadrado promedio 0.800455609669
# Error radio 0.00148246520431
# ...

# %%
import numpy as np
from matplotlib import pyplot as pp

x = np.random.randn(10000)
counts,bin_edges = np.histogram(x,20)
bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
err = np.random.rand(bin_centres.size)*100
pp.errorbar(bin_centres, counts, yerr=err, fmt='o')

pp.show()
